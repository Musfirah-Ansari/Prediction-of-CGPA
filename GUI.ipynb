# %%
import tkinter as tk
from tkinter import * #to use all packages
from tkinter import messagebox

# %%
window = tk.Tk()
window.title("Prediction of Cumulative Grade Point Average")

ltitle = tk.Label(window, text = "|Prediction of Cumulative Grade Point Average|", font = ("Times New Roman",20))
ltitle.place(x=400, y=0)

m1 = tk.Label(window, text = "MODEL 1(FE)", font = ("Arial Black",16))
m1.place(x=50, y=30)

h1 = tk.Label(window, text = "COURSE CODES    &    GPs", font = ("Helvetica 13 underline"))
h1.place(x=0, y=60)

m2 = tk.Label(window, text = "MODEL 2(FE+SE)", font = ("Arial Black",16))
m2.place(x=520, y=30)

h2 = tk.Label(window, text = "COURSE CODES    &    GPs", font = ("Helvetica 13 underline"))
h2.place(x=500, y=60)

m3 = tk.Label(window, text = "MODEL 3(FE+SE+TE)", font = ("Arial Black",16))
m3.place(x=1000, y=30)

h3 = tk.Label(window, text = "COURSE CODES    &    GPs", font = ("Helvetica 13 underline"))
h3.place(x=1000, y=60)

l1 = tk.Label(window, text = "PH-121", font = ("Algerian",18))
l1.place(x=0, y=100) #position of this label we can use grid pack and place

t1 = tk.Entry(window, width = 20, border= 5)
t1.place(x=100, y=100)

l2 = tk.Label(window, text = "HS-101", font = ("Algerian",18))
l2.place(x=0, y=150)

t2 = tk.Entry(window, width = 20, border= 5)
t2.place(x=100, y=150)

l3 = tk.Label(window, text = "CY-105", font = ("Algerian",18))
l3.place(x=0, y=200)

t3 = tk.Entry(window, width = 20, border= 5)
t3.place(x=100, y=200)

l4 = tk.Label(window, text = "HS-105/12", font = ("Algerian",14))
l4.place(x=0, y=250)

t4 = tk.Entry(window, width = 20, border= 5)
t4.place(x=100, y=250)

l5 = tk.Label(window, text = "MT-111", font = ("Algerian",18))
l5.place(x=0, y=300)

t5 = tk.Entry(window, width = 20, border= 5)
t5.place(x=100, y=300)

l6 = tk.Label(window, text = "CS-105", font = ("Algerian",18))
l6.place(x=0, y=350)

t6 = tk.Entry(window, width = 20, border= 5)
t6.place(x=100, y=350)

l7 = tk.Label(window, text = "CS-106", font = ("Algerian",18))
l7.place(x=0, y=400)

t7 = tk.Entry(window, width = 20, border= 5)
t7.place(x=100, y=400)

l8 = tk.Label(window, text = "CS-107", font = ("Algerian",18))
l8.place(x=0, y=450)

t8 = tk.Entry(window, width = 20, border= 5)
t8.place(x=100, y=450)

l9 = tk.Label(window, text = "EL-102", font = ("Algerian",18))
l9.place(x=0, y=500)

t9 = tk.Entry(window, width = 20, border= 5)
t9.place(x=100, y=500)

l10 = tk.Label(window, text = "EE-119", font = ("Algerian",18))
l10.place(x=0, y=550)

t10 = tk.Entry(window, width = 20, border= 5)
t10.place(x=100, y=550)

l11 = tk.Label(window, text = "ME-107", font = ("Algerian",18))
l11.place(x=0, y=600)

t11 = tk.Entry(window, width = 20, border= 5)
t11.place(x=100, y=600)

l12 = tk.Label(window, text = "HS-205/20", font = ("Algerian",15))
l12.place(x=500, y=100) 

t12 = tk.Entry(window, width = 20, border= 5)
t12.place(x=600, y=100)

l13 = tk.Label(window, text = "MT-222", font = ("Algerian",18))
l13.place(x=500, y=150)

t13 = tk.Entry(window, width = 20, border= 5)
t13.place(x=600, y=150)

l14 = tk.Label(window, text = "EE-222", font = ("Algerian",18))
l14.place(x=500, y=200)

t14 = tk.Entry(window, width = 20, border= 5)
t14.place(x=600, y=200)

l15 = tk.Label(window, text = "MT-224", font = ("Algerian",18))
l15.place(x=500, y=250)

t15 = tk.Entry(window, width = 20, border= 5)
t15.place(x=600, y=250)

l16 = tk.Label(window, text = "CS-210", font = ("Algerian",18))
l16.place(x=500, y=300)

t16 = tk.Entry(window, width = 20, border= 5)
t16.place(x=600, y=300)

l17 = tk.Label(window, text = "CS-211", font = ("Algerian",18))
l17.place(x=500, y=350)

t17 = tk.Entry(window, width = 20, border= 5)
t17.place(x=600, y=350)

l18 = tk.Label(window, text = "CS-203", font = ("Algerian",18))
l18.place(x=500, y=400)

t18 = tk.Entry(window, width = 20, border= 5)
t18.place(x=600, y=400)

l19 = tk.Label(window, text = "CS-214", font = ("Algerian",18))
l19.place(x=500, y=450)

t19 = tk.Entry(window, width = 20, border= 5)
t19.place(x=600, y=450)

l20 = tk.Label(window, text = "EL-217", font = ("Algerian",18))
l20.place(x=500, y=500)

t20 = tk.Entry(window, width = 20, border= 5)
t20.place(x=600, y=500)

l21 = tk.Label(window, text = "CS-212", font = ("Algerian",18))
l21.place(x=500, y=550)

t21 = tk.Entry(window, width = 20, border= 5)
t21.place(x=600, y=550)

l22 = tk.Label(window, text = "CS-215", font = ("Algerian",18))
l22.place(x=500, y=600)

t22 = tk.Entry(window, width = 20, border= 5)
t22.place(x=600, y=600)

l23 = tk.Label(window, text = "MT-331", font = ("Algerian",18))
l23.place(x=1000, y=100) 

t23 = tk.Entry(window, width = 20, border= 5)
t23.place(x=1100, y=100)

l24 = tk.Label(window, text = "EF-303", font = ("Algerian",18))
l24.place(x=1000, y=150)

t24 = tk.Entry(window, width = 20, border= 5)
t24.place(x=1100, y=150)

l25 = tk.Label(window, text = "HS-304", font = ("Algerian",18))
l25.place(x=1000, y=200)

t25 = tk.Entry(window, width = 20, border= 5)
t25.place(x=1100, y=200)

l26 = tk.Label(window, text = "CS-301", font = ("Algerian",18))
l26.place(x=1000, y=250)

t26 = tk.Entry(window, width = 20, border= 5)
t26.place(x=1100, y=250)

l27 = tk.Label(window, text = "CS-302", font = ("Algerian",18))
l27.place(x=1000, y=300)

t27 = tk.Entry(window, width = 20, border= 5)
t27.place(x=1100, y=300)

l28 = tk.Label(window, text = "TC-383", font = ("Algerian",18))
l28.place(x=1000, y=350)

t28 = tk.Entry(window, width = 20, border= 5)
t28.place(x=1100, y=350)

l29 = tk.Label(window, text = "EL-332", font = ("Algerian",18))
l29.place(x=1000, y=400)

t29 = tk.Entry(window, width = 20, border= 5)
t29.place(x=1100, y=400)

l30 = tk.Label(window, text = "CS-318", font = ("Algerian",18))
l30.place(x=1000, y=450)

t30 = tk.Entry(window, width = 20, border= 5)
t30.place(x=1100, y=450)

l31 = tk.Label(window, text = "CS-306", font = ("Algerian",18))
l31.place(x=1000, y=500)

t31 = tk.Entry(window, width = 20, border= 5)
t31.place(x=1100, y=500)

l32 = tk.Label(window, text = "CS-312", font = ("Algerian",18))
l32.place(x=1000, y=550)

t32 = tk.Entry(window, width = 20, border= 5)
t32.place(x=1100, y=550)

l33 = tk.Label(window, text = "CS-317", font = ("Algerian",18))
l33.place(x=1000, y=600)

t33 = tk.Entry(window, width = 20, border= 5)
t33.place(x=1100, y=600)


b1 = tk.Button(window, text = "SUBMIT", font = ("Arial Bold", 18),bg = "white", fg = "red")
b1.place(x=600, y=650)

window.geometry("600x600") #size of window
window.mainloop() #togetwindow visible
